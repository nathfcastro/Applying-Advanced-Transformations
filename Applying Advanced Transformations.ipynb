# %% [markdown]
# # Applying Advanced Transformations
# Student Name: Nathalie Castro

# %%
import json
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data Loading

# %%
pd.set_option('display.max_columns', None)

# %%
powers_url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQ2cMaGI74T_DqeCWDojRIyUCQqNZxsu_L3f42JJKV-_f873im-CBttJU8qn_Kan22qa71uCXfDWdMI/pub?output=csv"
# Load the data
powers_df = pd.read_csv(powers_url)
# Verify it loaded
powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
info_url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRgXxC_AvDsxnrZSMIuKnPMvrSrL6ZnoLogMNU-ZD8uOB88pbsINNtkii1PlMTgWPSyrqm5JJnU6pCr/pub?output=csv"
# Load the data
info_df = pd.read_csv(info_url)
# Verify it loaded
info_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %% [markdown]
# ### Data Cleaning

# %%
# Check for missing values
info_df.isna().sum().sum()
# Out:
# 0

# %%
# Check for missing values
powers_df.isna().sum().sum()
# Out:
# 0

# %%
# Check for duplicates
info_df.duplicated().sum()
# Out:
# 0

# %%
# Check for duplicates
powers_df.duplicated().sum()
# Out:
# 0

# %%
# Split the "Hero|Publisher" column using split and save the 
info_df[["Hero", "Publisher"]] = info_df["Hero|Publisher"].str.split("|", expand=True)
# Drop the original column
info_df.drop("Hero|Publisher", axis=1, inplace=True)
# Verify it worked
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
# Separate Height From Weight
a = info_df.loc[0, "Measurements"]
type(json.loads(a.replace("'", '"')))
# Out:
# dict

# %%
info_df["Measurements"] = info_df["Measurements"].str.replace("'", '"')
# Apply JSON loads to the whole column to make the 
# string into a dictionary
info_df["Measurements"] = info_df["Measurements"].apply(json.loads)
# Verify it worked
info_df["Measurements"].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
# Create a DataFrame with just the height and weights
heights_weights = info_df["Measurements"].apply(pd.Series)
heights_weights.head()
# Out:
#      Height    Weight
# 0  203.0 cm  441.0 kg
# 1  191.0 cm   65.0 kg
# 2  185.0 cm   90.0 kg
# 3  203.0 cm  441.0 kg
# 4  193.0 cm  122.0 kg

# %%
# Rename the columns of the height weight dataframe
heights_weights.rename(columns = {"Height": "Height (cm)", "Weight": "Weight (kg)"}, inplace=True)
heights_weights.head()
# Out:
#   Height (cm) Weight (kg)
# 0    203.0 cm    441.0 kg
# 1    191.0 cm     65.0 kg
# 2    185.0 cm     90.0 kg
# 3    203.0 cm    441.0 kg
# 4    193.0 cm    122.0 kg

# %%
# Remove units from the measurements strings then cast each as a float
heights_weights["Height (cm)"] = heights_weights["Height (cm)"].str.split(" ", expand=True)[0].astype(float)
heights_weights["Weight (kg)"] = heights_weights["Weight (kg)"].str.split(" ", expand=True)[0].astype(float)
# Verify floats
heights_weights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Height (cm)  463 non-null    float64
#  1   Weight (kg)  463 non-null    float64
# dtypes: float64(2)
# memory usage: 7.4 KB

# %%
# Add the heights_weights dataframe to the original
info_df = pd.concat([info_df, heights_weights], axis=1)
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher  Height (cm)  Weight (kg)
# 0      Marvel Comics        203.0        441.0
# 1  Dark Horse Comics        191.0         65.0
# 2          DC Comics        185.0         90.0
# 3      Marvel Comics        203.0        441.0
# 4      Marvel Comics        193.0        122.0

# %%
# Remove the original "Measurements" column
info_df.drop(columns="Measurements", inplace=True)
info_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height (cm)  Weight (kg)
# 0         A-Bomb      Marvel Comics        203.0        441.0
# 1     Abe Sapien  Dark Horse Comics        191.0         65.0
# 2       Abin Sur          DC Comics        185.0         90.0
# 3    Abomination      Marvel Comics        203.0        441.0
# 4  Absorbing Man      Marvel Comics        193.0        122.0

# %%
# Make the columns into a list
columns = list(info_df.columns)
columns
# Out:
# ['Gender',
#  'Race',
#  'Alignment',
#  'Hair color',
#  'Eye color',
#  'Skin color',
#  'Hero',
#  'Publisher',
#  'Height (cm)',
#  'Weight (kg)']

# %%
# Rearrange columns
columns = [columns[columns.index("Hero")], \
           columns[columns.index("Publisher")], \
           columns[columns.index("Alignment")],\
           columns[columns.index("Gender")], \
           columns[columns.index("Race")], \
           columns[columns.index("Height (cm)")], \
           columns[columns.index("Weight (kg)")], \
           columns[columns.index("Skin color")], \
           columns[columns.index("Eye color")], \
           columns[columns.index("Hair color")]]
columns
# Out:
# ['Hero',
#  'Publisher',
#  'Alignment',
#  'Gender',
#  'Race',
#  'Height (cm)',
#  'Weight (kg)',
#  'Skin color',
#  'Eye color',
#  'Hair color']

# %%
# Apply the new rearrangement to the old info_df
info_df = info_df[columns]
info_df.head()
# Out:
#             Hero          Publisher Alignment Gender               Race  \
# 0         A-Bomb      Marvel Comics      good   Male              Human
# 1     Abe Sapien  Dark Horse Comics      good   Male      Icthyo Sapien
# 2       Abin Sur          DC Comics      good   Male            Ungaran
# 3    Abomination      Marvel Comics       bad   Male  Human / Radiation
# 4  Absorbing Man      Marvel Comics       bad   Male              Human
#
#    Height (cm)  Weight (kg) Skin color Eye color Hair color
# 0        203.0        441.0    Unknown    yellow    No Hair
# 1        191.0         65.0       blue      blue    No Hair
# 2        185.0         90.0        red      blue    No Hair
# 3        203.0        441.0    Unknown     green    No Hair
# 4        193.0        122.0    Unknown      blue    No Hair

# %% [markdown]
# ### OHE

# %%
# Split the "Powers" string by commas into a list
powers_df["Powers Split"] = powers_df["Powers"].str.split(",")
powers_df.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers Split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
# Create a new DataFrame of exploded powers
powers_exploded = powers_df.explode("Powers Split")
# Find the unique powers in the exploded column
unique_powers = np.sort(powers_exploded["Powers Split"].unique())
unique_powers
# Out:
# array(['Accelerated Healing', 'Adaptation', 'Agility',
#        'Animal Attributes', 'Animal Control', 'Animal Oriented Powers',
#        'Animation', 'Anti-Gravity', 'Astral Projection', 'Astral Travel',
#        'Audio Control', 'Banish', 'Biokinesis', 'Camouflage',
#        'Changing Armor', 'Clairvoyance', 'Cloaking', 'Cold Resistance',
#        'Cryokinesis', 'Danger Sense', 'Darkforce Manipulation',
#        'Death Touch', 'Density Control', 'Dexterity',
#        'Dimensional Awareness', 'Dimensional Travel', 'Duplication',
#        'Durability', 'Echolocation', 'Elasticity', 'Electrical Transport',
#        'Electrokinesis', 'Element Control',
#        'Elemental Transmogrification', 'Empathy', 'Energy Absorption',
#        'Energy Armor', 'Energy Beams', 'Energy Blasts',
#        'Energy Constructs', 'Energy Manipulation', 'Energy Resistance',
#        'Enhanced Hearing', 'Enhanced Memory', 'Enhanced Senses',
#        'Enhanced Sight', 'Enhanced Smell', 'Enhanced Touch',
#        'Fire Control', 'Fire Resistance', 'Flight', 'Force Fields',
#        'Gliding', 'Gravity Control', 'Grim Reaping', 'Hair Manipulation',
#        'Heat Generation', 'Heat Resistance', 'Hyperkinesis',
#        'Hypnokinesis', 'Illumination', 'Illusions', 'Immortality',
#        'Insanity', 'Intangibility', 'Intelligence', 'Intuitive aptitude',
#        'Invisibility', 'Invulnerability', 'Jump', 'Lantern Power Ring',
#        'Levitation', 'Light Control', 'Longevity', 'Magic',
#        'Magic Resistance', 'Magnetism', 'Marksmanship',
#        'Matter Absorption', 'Melting', 'Mind Blast', 'Mind Control',
#        'Mind Control Resistance', 'Molecular Combustion',
#        'Molecular Dissipation', 'Molecular Manipulation', 'Natural Armor',
#        'Natural Weapons', 'Nova Force', 'Odin Force', 'Omnilingualism',
#        'Omnipotent', 'Omnipresent', 'Omniscient', 'Omnitrix',
#        'Peak Human Condition', 'Phasing', 'Phoenix Force',
#        'Photographic Reflexes', 'Plant Control', 'Portal Creation',
#        'Possession', 'Power Absorption', 'Power Augmentation',
#        'Power Cosmic', 'Power Nullifier', 'Power Sense', 'Power Suit',
#        'Precognition', 'Probability Manipulation', 'Projection',
#        'Psionic Powers', 'Qwardian Power Ring', 'Radar Sense',
#        'Radiation Absorption', 'Radiation Control', 'Radiation Immunity',
#        'Reality Warping', 'Reflexes', 'Regeneration', 'Resurrection',
#        'Seismic Power', 'Self-Sustenance', 'Shapeshifting',
#        'Size Changing', 'Sonar', 'Sonic Scream', 'Spatial Awareness',
#        'Speed Force', 'Stamina', 'Stealth', 'Sub-Mariner',
#        'Substance Secretion', 'Summoning', 'Super Breath', 'Super Speed',
#        'Super Strength', 'Symbiote Costume', 'Technopath/Cyberpath',
#        'Telekinesis', 'Telepathy', 'Telepathy Resistance',
#        'Teleportation', 'Terrakinesis', 'The Force', 'Thirstokinesis',
#        'Time Manipulation', 'Time Travel', 'Toxin and Disease Control',
#        'Toxin and Disease Resistance', 'Underwater breathing',
#        'Vision - Cryo', 'Vision - Heat', 'Vision - Infrared',
#        'Vision - Microscopic', 'Vision - Night', 'Vision - Telescopic',
#        'Vision - Thermal', 'Vision - X-Ray', 'Vitakinesis',
#        'Wallcrawling', 'Water Control', 'Weapon-based Powers',
#        'Weapons Master', 'Weather Control', 'Web Creation',
#        'Wind Control'], dtype=object)

# %%
# Create each power column and add true/false values 
for power in unique_powers:
    power_df = pd.DataFrame({power: powers_df["Powers"].str.contains(power)})
    powers_df = pd.concat([powers_df, power_df], axis=1)
powers_df.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers Split  Accelerated Healing  \
# 0    [Agility, Super Strength, Stamina, Super Speed]                False
# 1  [Accelerated Healing, Durability, Longevity, S...                 True
# 2  [Agility, Accelerated Healing, Cold Resistance...                 True
# 3                               [Lantern Power Ring]                False
# 4  [Accelerated Healing, Intelligence, Super Stre...                 True
#
#    Adaptation  Agility  Animal Attributes  Animal Control  \
# 0       False     True              False           False
# 1       False    False              False           False
# 2       False     True              False           False
# 3       False    False              False           False
# 4       False    False              False           False
#
#    Animal Oriented Powers  Animation  Anti-Gravity  Astral Projection  \
# 0                   False      False         False              False
# 1                   False      False         False              False
# 2                   False      False         False              False
# 3                   False      False         False              False
# 4                   False       True         False              False
#
#    Astral Travel  Audio Control  Banish  Biokinesis  Camouflage  \
# 0          False          False   False       False       False
# 1          False          False   False       False        True
# 2          False          False   False       False       False
# 3          False          False   False       False       False
# 4          False          False   False       False       False
#
#    Changing Armor  Clairvoyance  Cloaking  Cold Resistance  Cryokinesis  \
# 0           False         False     False            False        False
# 1           False         False     False            False        False
# 2           False         False     False             True        False
# 3           False         False     False            False        False
# 4           False         False     False            False        False
#
#    Danger Sense  Darkforce Manipulation  Death Touch  Density Control  \
# 0         False                   False        False            False
# 1         False                   False        False            False
# 2         False                   False        False            False
# 3         False                   False        False            False
# 4         False                   False        False            False
#
#    Dexterity  Dimensional Awareness  Dimensional Travel  Duplication  \
# 0      False                  False               False        False
# 1      False                  False               False        False
# 2      False                  False               False        False
# 3      False                  False               False        False
# 4      False                  False               False        False
#
#    Durability  Echolocation  Elasticity  Electrical Transport  Electrokinesis  \
# 0       False         False       False                 False           False
# 1        True         False       False                 False           False
# 2        True         False       False                 False           False
# 3       False         False       False                 False           False
# 4       False         False       False                 False           False
#
#    Element Control  Elemental Transmogrification  Empathy  Energy Absorption  \
# 0            False                         False    False              False
# 1            False                         False    False              False
# 2            False                         False    False              False
# 3            False                         False    False              False
# 4            False                         False    False              False
#
#    Energy Armor  Energy Beams  Energy Blasts  Energy Constructs  \
# 0         False         False          False              False
# 1         False         False          False              False
# 2         False         False          False              False
# 3         False         False          False              False
# 4         False         False          False              False
#
#    Energy Manipulation  Energy Resistance  Enhanced Hearing  Enhanced Memory  \
# 0                False              False             False            False
# 1                False              False             False            False
# 2                False              False             False            False
# 3                False              False             False            False
# 4                False              False             False            False
#
#    Enhanced Senses  Enhanced Sight  Enhanced Smell  Enhanced Touch  \
# 0            False           False           False           False
# 1            False           False           False           False
# 2            False            True           False           False
# 3            False           False           False           False
# 4            False           False           False           False
#
#    Fire Control  Fire Resistance  Flight  Force Fields  Gliding  \
# 0         False            False   False         False    False
# 1         False            False   False         False    False
# 2         False            False   False         False    False
# 3         False            False   False         False    False
# 4         False            False   False         False    False
#
#    Gravity Control  Grim Reaping  Hair Manipulation  Heat Generation  \
# 0            False         False              False            False
# 1            False         False              False            False
# 2            False         False              False            False
# 3            False         False              False            False
# 4            False         False              False            False
#
#    Heat Resistance  Hyperkinesis  Hypnokinesis  Illumination  Illusions  \
# 0            False         False         False         False      False
# 1            False         False         False         False      False
# 2            False         False         False         False      False
# 3            False         False         False         False      False
# 4            False         False         False         False      False
#
#    Immortality  Insanity  Intangibility  Intelligence  Intuitive aptitude  \
# 0        False     False          False         False               False
# 1        False     False          False         False               False
# 2         True     False          False          True               False
# 3        False     False          False         False               False
# 4        False     False          False          True               False
#
#    Invisibility  Invulnerability   Jump  Lantern Power Ring  Levitation  \
# 0         False            False  False               False       False
# 1         False            False  False               False       False
# 2         False            False  False               False       False
# 3         False            False  False                True       False
# 4         False             True  False               False       False
#
#    Light Control  Longevity  Magic  Magic Resistance  Magnetism  Marksmanship  \
# 0          False      False  False             False      False         False
# 1          False       True  False             False      False         False
# 2          False       True  False             False      False          True
# 3          False      False  False             False      False         False
# 4          False      False  False             False      False         False
#
#    Matter Absorption  Melting  Mind Blast  Mind Control  \
# 0              False    False       False         False
# 1              False    False       False         False
# 2              False    False       False         False
# 3              False    False       False         False
# 4              False    False       False         False
#
#    Mind Control Resistance  Molecular Combustion  Molecular Dissipation  \
# 0                    False                 False                  False
# 1                    False                 False                  False
# 2                    False                 False                  False
# 3                    False                 False                  False
# 4                    False                 False                  False
#
#    Molecular Manipulation  Natural Armor  Natural Weapons  Nova Force  \
# 0                   False          False            False       False
# 1                   False          False            False       False
# 2                   False          False            False       False
# 3                   False          False            False       False
# 4                   False          False            False       False
#
#    Odin Force  Omnilingualism  Omnipotent  Omnipresent  Omniscient  Omnitrix  \
# 0       False           False       False        False       False     False
# 1       False           False       False        False       False     False
# 2       False           False       False        False       False     False
# 3       False           False       False        False       False     False
# 4       False           False       False        False       False     False
#
#    Peak Human Condition  Phasing  Phoenix Force  Photographic Reflexes  \
# 0                 False    False          False                  False
# 1                 False    False          False                  False
# 2                 False    False          False                  False
# 3                 False    False          False                  False
# 4                 False    False          False                  False
#
#    Plant Control  Portal Creation  Possession  Power Absorption  \
# 0          False            False       False             False
# 1          False            False       False             False
# 2          False            False       False             False
# 3          False            False       False             False
# 4          False            False       False             False
#
#    Power Augmentation  Power Cosmic  Power Nullifier  Power Sense  Power Suit  \
# 0               False         False            False        False       False
# 1               False         False            False        False       False
# 2               False         False            False        False       False
# 3               False         False            False        False       False
# 4               False         False            False        False       False
#
#    Precognition  Probability Manipulation  Projection  Psionic Powers  \
# 0         False                     False       False           False
# 1         False                     False       False           False
# 2         False                     False       False           False
# 3         False                     False       False           False
# 4         False                     False       False           False
#
#    Qwardian Power Ring  Radar Sense  Radiation Absorption  Radiation Control  \
# 0                False        False                 False              False
# 1                False        False                 False              False
# 2                False        False                 False              False
# 3                False        False                 False              False
# 4                False        False                 False              False
#
#    Radiation Immunity  Reality Warping  Reflexes  Regeneration  Resurrection  \
# 0               False            False     False         False         False
# 1               False            False     False         False         False
# 2               False            False      True         False         False
# 3               False            False     False         False         False
# 4               False            False     False         False         False
#
#    Seismic Power  Self-Sustenance  Shapeshifting  Size Changing  Sonar  \
# 0          False            False          False          False  False
# 1          False             True          False          False  False
# 2          False            False          False          False  False
# 3          False            False          False          False  False
# 4          False            False          False          False  False
#
#    Sonic Scream  Spatial Awareness  Speed Force  Stamina  Stealth  \
# 0         False              False        False     True    False
# 1         False              False        False     True    False
# 2         False              False        False     True    False
# 3         False              False        False    False    False
# 4         False              False        False     True    False
#
#    Sub-Mariner  Substance Secretion  Summoning  Super Breath  Super Speed  \
# 0        False                False      False         False         True
# 1        False                False      False         False        False
# 2         True                False      False         False        False
# 3        False                False      False         False        False
# 4        False                False      False          True         True
#
#    Super Strength  Symbiote Costume  Technopath/Cyberpath  Telekinesis  \
# 0            True             False                 False        False
# 1            True             False                 False        False
# 2            True             False                 False        False
# 3           False             False                 False        False
# 4            True             False                 False        False
#
#    Telepathy  Telepathy Resistance  Teleportation  Terrakinesis  The Force  \
# 0      False                 False          False         False      False
# 1      False                 False          False         False      False
# 2       True                 False          False         False      False
# 3      False                 False          False         False      False
# 4      False                 False          False         False      False
#
#    Thirstokinesis  Time Manipulation  Time Travel  Toxin and Disease Control  \
# 0           False              False        False                      False
# 1           False              False        False                      False
# 2           False              False        False                      False
# 3           False              False        False                      False
# 4           False              False        False                      False
#
#    Toxin and Disease Resistance  Underwater breathing  Vision - Cryo  \
# 0                         False                 False          False
# 1                         False                 False          False
# 2                         False                  True          False
# 3                         False                 False          False
# 4                         False                 False          False
#
#    Vision - Heat  Vision - Infrared  Vision - Microscopic  Vision - Night  \
# 0          False              False                 False           False
# 1          False              False                 False           False
# 2          False              False                 False           False
# 3          False              False                 False           False
# 4          False              False                 False           False
#
#    Vision - Telescopic  Vision - Thermal  Vision - X-Ray  Vitakinesis  \
# 0                False             False           False        False
# 1                False             False           False        False
# 2                False             False           False        False
# 3                False             False           False        False
# 4                False             False           False        False
#
#    Wallcrawling  Water Control  Weapon-based Powers  Weapons Master  \
# 0         False          False                False           False
# 1         False          False                False           False
# 2         False          False                False            True
# 3         False          False                False           False
# 4         False          False                False           False
#
#    Weather Control  Web Creation  Wind Control
# 0            False         False         False
# 1            False         False         False
# 2            False         False         False
# 3            False         False         False
# 4            False         False         False

# %%
# Drop the now unnecessary Power and Power Split columns
powers_df.drop(columns=["Powers", "Powers Split"], inplace=True)
powers_df.head()
# Out:
#     hero_names  Accelerated Healing  Adaptation  Agility  Animal Attributes  \
# 0      3-D Man                False       False     True              False
# 1       A-Bomb                 True       False    False              False
# 2   Abe Sapien                 True       False     True              False
# 3     Abin Sur                False       False    False              False
# 4  Abomination                 True       False    False              False
#
#    Animal Control  Animal Oriented Powers  Animation  Anti-Gravity  \
# 0           False                   False      False         False
# 1           False                   False      False         False
# 2           False                   False      False         False
# 3           False                   False      False         False
# 4           False                   False       True         False
#
#    Astral Projection  Astral Travel  Audio Control  Banish  Biokinesis  \
# 0              False          False          False   False       False
# 1              False          False          False   False       False
# 2              False          False          False   False       False
# 3              False          False          False   False       False
# 4              False          False          False   False       False
#
#    Camouflage  Changing Armor  Clairvoyance  Cloaking  Cold Resistance  \
# 0       False           False         False     False            False
# 1        True           False         False     False            False
# 2       False           False         False     False             True
# 3       False           False         False     False            False
# 4       False           False         False     False            False
#
#    Cryokinesis  Danger Sense  Darkforce Manipulation  Death Touch  \
# 0        False         False                   False        False
# 1        False         False                   False        False
# 2        False         False                   False        False
# 3        False         False                   False        False
# 4        False         False                   False        False
#
#    Density Control  Dexterity  Dimensional Awareness  Dimensional Travel  \
# 0            False      False                  False               False
# 1            False      False                  False               False
# 2            False      False                  False               False
# 3            False      False                  False               False
# 4            False      False                  False               False
#
#    Duplication  Durability  Echolocation  Elasticity  Electrical Transport  \
# 0        False       False         False       False                 False
# 1        False        True         False       False                 False
# 2        False        True         False       False                 False
# 3        False       False         False       False                 False
# 4        False       False         False       False                 False
#
#    Electrokinesis  Element Control  Elemental Transmogrification  Empathy  \
# 0           False            False                         False    False
# 1           False            False                         False    False
# 2           False            False                         False    False
# 3           False            False                         False    False
# 4           False            False                         False    False
#
#    Energy Absorption  Energy Armor  Energy Beams  Energy Blasts  \
# 0              False         False         False          False
# 1              False         False         False          False
# 2              False         False         False          False
# 3              False         False         False          False
# 4              False         False         False          False
#
#    Energy Constructs  Energy Manipulation  Energy Resistance  \
# 0              False                False              False
# 1              False                False              False
# 2              False                False              False
# 3              False                False              False
# 4              False                False              False
#
#    Enhanced Hearing  Enhanced Memory  Enhanced Senses  Enhanced Sight  \
# 0             False            False            False           False
# 1             False            False            False           False
# 2             False            False            False            True
# 3             False            False            False           False
# 4             False            False            False           False
#
#    Enhanced Smell  Enhanced Touch  Fire Control  Fire Resistance  Flight  \
# 0           False           False         False            False   False
# 1           False           False         False            False   False
# 2           False           False         False            False   False
# 3           False           False         False            False   False
# 4           False           False         False            False   False
#
#    Force Fields  Gliding  Gravity Control  Grim Reaping  Hair Manipulation  \
# 0         False    False            False         False              False
# 1         False    False            False         False              False
# 2         False    False            False         False              False
# 3         False    False            False         False              False
# 4         False    False            False         False              False
#
#    Heat Generation  Heat Resistance  Hyperkinesis  Hypnokinesis  Illumination  \
# 0            False            False         False         False         False
# 1            False            False         False         False         False
# 2            False            False         False         False         False
# 3            False            False         False         False         False
# 4            False            False         False         False         False
#
#    Illusions  Immortality  Insanity  Intangibility  Intelligence  \
# 0      False        False     False          False         False
# 1      False        False     False          False         False
# 2      False         True     False          False          True
# 3      False        False     False          False         False
# 4      False        False     False          False          True
#
#    Intuitive aptitude  Invisibility  Invulnerability   Jump  \
# 0               False         False            False  False
# 1               False         False            False  False
# 2               False         False            False  False
# 3               False         False            False  False
# 4               False         False             True  False
#
#    Lantern Power Ring  Levitation  Light Control  Longevity  Magic  \
# 0               False       False          False      False  False
# 1               False       False          False       True  False
# 2               False       False          False       True  False
# 3                True       False          False      False  False
# 4               False       False          False      False  False
#
#    Magic Resistance  Magnetism  Marksmanship  Matter Absorption  Melting  \
# 0             False      False         False              False    False
# 1             False      False         False              False    False
# 2             False      False          True              False    False
# 3             False      False         False              False    False
# 4             False      False         False              False    False
#
#    Mind Blast  Mind Control  Mind Control Resistance  Molecular Combustion  \
# 0       False         False                    False                 False
# 1       False         False                    False                 False
# 2       False         False                    False                 False
# 3       False         False                    False                 False
# 4       False         False                    False                 False
#
#    Molecular Dissipation  Molecular Manipulation  Natural Armor  \
# 0                  False                   False          False
# 1                  False                   False          False
# 2                  False                   False          False
# 3                  False                   False          False
# 4                  False                   False          False
#
#    Natural Weapons  Nova Force  Odin Force  Omnilingualism  Omnipotent  \
# 0            False       False       False           False       False
# 1            False       False       False           False       False
# 2            False       False       False           False       False
# 3            False       False       False           False       False
# 4            False       False       False           False       False
#
#    Omnipresent  Omniscient  Omnitrix  Peak Human Condition  Phasing  \
# 0        False       False     False                 False    False
# 1        False       False     False                 False    False
# 2        False       False     False                 False    False
# 3        False       False     False                 False    False
# 4        False       False     False                 False    False
#
#    Phoenix Force  Photographic Reflexes  Plant Control  Portal Creation  \
# 0          False                  False          False            False
# 1          False                  False          False            False
# 2          False                  False          False            False
# 3          False                  False          False            False
# 4          False                  False          False            False
#
#    Possession  Power Absorption  Power Augmentation  Power Cosmic  \
# 0       False             False               False         False
# 1       False             False               False         False
# 2       False             False               False         False
# 3       False             False               False         False
# 4       False             False               False         False
#
#    Power Nullifier  Power Sense  Power Suit  Precognition  \
# 0            False        False       False         False
# 1            False        False       False         False
# 2            False        False       False         False
# 3            False        False       False         False
# 4            False        False       False         False
#
#    Probability Manipulation  Projection  Psionic Powers  Qwardian Power Ring  \
# 0                     False       False           False                False
# 1                     False       False           False                False
# 2                     False       False           False                False
# 3                     False       False           False                False
# 4                     False       False           False                False
#
#    Radar Sense  Radiation Absorption  Radiation Control  Radiation Immunity  \
# 0        False                 False              False               False
# 1        False                 False              False               False
# 2        False                 False              False               False
# 3        False                 False              False               False
# 4        False                 False              False               False
#
#    Reality Warping  Reflexes  Regeneration  Resurrection  Seismic Power  \
# 0            False     False         False         False          False
# 1            False     False         False         False          False
# 2            False      True         False         False          False
# 3            False     False         False         False          False
# 4            False     False         False         False          False
#
#    Self-Sustenance  Shapeshifting  Size Changing  Sonar  Sonic Scream  \
# 0            False          False          False  False         False
# 1             True          False          False  False         False
# 2            False          False          False  False         False
# 3            False          False          False  False         False
# 4            False          False          False  False         False
#
#    Spatial Awareness  Speed Force  Stamina  Stealth  Sub-Mariner  \
# 0              False        False     True    False        False
# 1              False        False     True    False        False
# 2              False        False     True    False         True
# 3              False        False    False    False        False
# 4              False        False     True    False        False
#
#    Substance Secretion  Summoning  Super Breath  Super Speed  Super Strength  \
# 0                False      False         False         True            True
# 1                False      False         False        False            True
# 2                False      False         False        False            True
# 3                False      False         False        False           False
# 4                False      False          True         True            True
#
#    Symbiote Costume  Technopath/Cyberpath  Telekinesis  Telepathy  \
# 0             False                 False        False      False
# 1             False                 False        False      False
# 2             False                 False        False       True
# 3             False                 False        False      False
# 4             False                 False        False      False
#
#    Telepathy Resistance  Teleportation  Terrakinesis  The Force  \
# 0                 False          False         False      False
# 1                 False          False         False      False
# 2                 False          False         False      False
# 3                 False          False         False      False
# 4                 False          False         False      False
#
#    Thirstokinesis  Time Manipulation  Time Travel  Toxin and Disease Control  \
# 0           False              False        False                      False
# 1           False              False        False                      False
# 2           False              False        False                      False
# 3           False              False        False                      False
# 4           False              False        False                      False
#
#    Toxin and Disease Resistance  Underwater breathing  Vision - Cryo  \
# 0                         False                 False          False
# 1                         False                 False          False
# 2                         False                  True          False
# 3                         False                 False          False
# 4                         False                 False          False
#
#    Vision - Heat  Vision - Infrared  Vision - Microscopic  Vision - Night  \
# 0          False              False                 False           False
# 1          False              False                 False           False
# 2          False              False                 False           False
# 3          False              False                 False           False
# 4          False              False                 False           False
#
#    Vision - Telescopic  Vision - Thermal  Vision - X-Ray  Vitakinesis  \
# 0                False             False           False        False
# 1                False             False           False        False
# 2                False             False           False        False
# 3                False             False           False        False
# 4                False             False           False        False
#
#    Wallcrawling  Water Control  Weapon-based Powers  Weapons Master  \
# 0         False          False                False           False
# 1         False          False                False           False
# 2         False          False                False            True
# 3         False          False                False           False
# 4         False          False                False           False
#
#    Weather Control  Web Creation  Wind Control
# 0            False         False         False
# 1            False         False         False
# 2            False         False         False
# 3            False         False         False
# 4            False         False         False

# %%
# Merge the tables for values where "Hero" = "hero_names" and then drop the "hero_names" column
final_df = pd.merge(info_df, powers_df, left_on="Hero", right_on="hero_names").drop(columns="hero_names")
final_df
# Out:
#                 Hero          Publisher Alignment  Gender               Race  \
# 0             A-Bomb      Marvel Comics      good    Male              Human
# 1         Abe Sapien  Dark Horse Comics      good    Male      Icthyo Sapien
# 2           Abin Sur          DC Comics      good    Male            Ungaran
# 3        Abomination      Marvel Comics       bad    Male  Human / Radiation
# 4      Absorbing Man      Marvel Comics       bad    Male              Human
# ..               ...                ...       ...     ...                ...
# 458     Yellowjacket      Marvel Comics      good    Male              Human
# 459  Yellowjacket II      Marvel Comics      good  Female              Human
# 460             Yoda       George Lucas      good    Male     Yoda's species
# 461          Zatanna          DC Comics      good  Female              Human
# 462             Zoom          DC Comics       bad    Male            Unknown
#
#      Height (cm)  Weight (kg) Skin color Eye color        Hair color  \
# 0          203.0        441.0    Unknown    yellow           No Hair
# 1          191.0         65.0       blue      blue           No Hair
# 2          185.0         90.0        red      blue           No Hair
# 3          203.0        441.0    Unknown     green           No Hair
# 4          193.0        122.0    Unknown      blue           No Hair
# ..           ...          ...        ...       ...               ...
# 458        183.0         83.0    Unknown      blue             Blond
# 459        165.0         52.0    Unknown      blue  Strawberry Blond
# 460         66.0         17.0      green     brown             White
# 461        170.0         57.0    Unknown      blue             Black
# 462        185.0         81.0    Unknown       red             Brown
#
#      Accelerated Healing  Adaptation  Agility  Animal Attributes  \
# 0                   True       False    False              False
# 1                   True       False     True              False
# 2                  False       False    False              False
# 3                   True       False    False              False
# 4                  False       False    False              False
# ..                   ...         ...      ...                ...
# 458                False       False    False              False
# 459                False       False    False              False
# 460                False       False     True              False
# 461                False       False    False              False
# 462                False       False    False              False
#
#      Animal Control  Animal Oriented Powers  Animation  Anti-Gravity  \
# 0             False                   False      False         False
# 1             False                   False      False         False
# 2             False                   False      False         False
# 3             False                   False       True         False
# 4             False                   False      False         False
# ..              ...                     ...        ...           ...
# 458           False                    True      False         False
# 459           False                   False      False         False
# 460           False                   False      False         False
# 461           False                   False      False         False
# 462           False                   False      False         False
#
#      Astral Projection  Astral Travel  Audio Control  Banish  Biokinesis  \
# 0                False          False          False   False       False
# 1                False          False          False   False       False
# 2                False          False          False   False       False
# 3                False          False          False   False       False
# 4                False          False          False   False       False
# ..                 ...            ...            ...     ...         ...
# 458              False          False          False   False       False
# 459              False          False          False   False       False
# 460              False          False          False   False       False
# 461              False          False          False   False       False
# 462              False          False          False   False       False
#
#      Camouflage  Changing Armor  Clairvoyance  Cloaking  Cold Resistance  \
# 0          True           False         False     False            False
# 1         False           False         False     False             True
# 2         False           False         False     False            False
# 3         False           False         False     False            False
# 4         False           False         False     False             True
# ..          ...             ...           ...       ...              ...
# 458       False           False         False     False            False
# 459       False           False         False     False            False
# 460       False           False         False      True            False
# 461       False           False         False     False            False
# 462       False           False         False     False            False
#
#      Cryokinesis  Danger Sense  Darkforce Manipulation  Death Touch  \
# 0          False         False                   False        False
# 1          False         False                   False        False
# 2          False         False                   False        False
# 3          False         False                   False        False
# 4          False         False                   False        False
# ..           ...           ...                     ...          ...
# 458        False         False                   False        False
# 459        False         False                   False        False
# 460        False          True                   False        False
# 461         True         False                   False        False
# 462        False         False                   False        False
#
#      Density Control  Dexterity  Dimensional Awareness  Dimensional Travel  \
# 0              False      False                  False               False
# 1              False      False                  False               False
# 2              False      False                  False               False
# 3              False      False                  False               False
# 4              False      False                  False               False
# ..               ...        ...                    ...                 ...
# 458            False      False                  False               False
# 459            False      False                  False               False
# 460            False      False                  False               False
# 461            False      False                  False               False
# 462            False      False                  False               False
#
#      Duplication  Durability  Echolocation  Elasticity  Electrical Transport  \
# 0          False        True         False       False                 False
# 1          False        True         False       False                 False
# 2          False       False         False       False                 False
# 3          False       False         False       False                 False
# 4          False        True         False       False                 False
# ..           ...         ...           ...         ...                   ...
# 458        False       False         False       False                 False
# 459        False       False         False       False                 False
# 460        False       False         False       False                 False
# 461        False       False         False       False                 False
# 462        False       False         False       False                 False
#
#      Electrokinesis  Element Control  Elemental Transmogrification  Empathy  \
# 0             False            False                         False    False
# 1             False            False                         False    False
# 2             False            False                         False    False
# 3             False            False                         False    False
# 4             False            False                          True    False
# ..              ...              ...                           ...      ...
# 458           False            False                         False    False
# 459           False            False                         False    False
# 460           False            False                         False     True
# 461           False            False                         False    False
# 462           False            False                         False    False
#
#      Energy Absorption  Energy Armor  Energy Beams  Energy Blasts  \
# 0                False         False         False          False
# 1                False         False         False          False
# 2                False         False         False          False
# 3                False         False         False          False
# 4                 True         False         False          False
# ..                 ...           ...           ...            ...
# 458              False         False         False          False
# 459              False         False         False           True
# 460              False         False         False           True
# 461              False         False         False          False
# 462              False         False         False          False
#
#      Energy Constructs  Energy Manipulation  Energy Resistance  \
# 0                False                False              False
# 1                False                False              False
# 2                False                False              False
# 3                False                False              False
# 4                False                False              False
# ..                 ...                  ...                ...
# 458              False                False              False
# 459              False                False              False
# 460              False                False              False
# 461              False                False              False
# 462              False                False              False
#
#      Enhanced Hearing  Enhanced Memory  Enhanced Senses  Enhanced Sight  \
# 0               False            False            False           False
# 1               False            False            False            True
# 2               False            False            False           False
# 3               False            False            False           False
# 4               False            False            False           False
# ..                ...              ...              ...             ...
# 458             False            False            False           False
# 459             False            False            False           False
# 460             False            False            False           False
# 461             False            False            False           False
# 462             False            False            False           False
#
#      Enhanced Smell  Enhanced Touch  Fire Control  Fire Resistance  Flight  \
# 0             False           False         False            False   False
# 1             False           False         False            False   False
# 2             False           False         False            False   False
# 3             False           False         False            False   False
# 4             False           False         False             True   False
# ..              ...             ...           ...              ...     ...
# 458           False           False         False            False   False
# 459           False           False         False            False    True
# 460           False           False         False            False   False
# 461           False           False          True            False   False
# 462           False           False         False            False   False
#
#      Force Fields  Gliding  Gravity Control  Grim Reaping  Hair Manipulation  \
# 0           False    False            False         False              False
# 1           False    False            False         False              False
# 2           False    False            False         False              False
# 3           False    False            False         False              False
# 4           False    False            False         False              False
# ..            ...      ...              ...           ...                ...
# 458         False    False            False         False              False
# 459         False    False            False         False              False
# 460          True    False            False         False              False
# 461         False    False            False         False              False
# 462         False    False            False         False              False
#
#      Heat Generation  Heat Resistance  Hyperkinesis  Hypnokinesis  \
# 0              False            False         False         False
# 1              False            False         False         False
# 2              False            False         False         False
# 3              False            False         False         False
# 4              False             True         False         False
# ..               ...              ...           ...           ...
# 458            False            False         False         False
# 459            False            False         False         False
# 460            False            False         False         False
# 461            False            False         False         False
# 462            False            False         False         False
#
#      Illumination  Illusions  Immortality  Insanity  Intangibility  \
# 0           False      False        False     False          False
# 1           False      False         True     False          False
# 2           False      False        False     False          False
# 3           False      False        False     False          False
# 4           False      False        False     False          False
# ..            ...        ...          ...       ...            ...
# 458         False      False        False     False          False
# 459         False      False        False     False          False
# 460         False      False        False     False          False
# 461         False      False        False     False          False
# 462         False      False        False     False           True
#
#      Intelligence  Intuitive aptitude  Invisibility  Invulnerability   Jump  \
# 0           False               False         False            False  False
# 1            True               False         False            False  False
# 2           False               False         False            False  False
# 3            True               False         False             True  False
# 4           False               False         False             True  False
# ..            ...                 ...           ...              ...    ...
# 458         False               False         False            False  False
# 459         False               False         False            False  False
# 460          True               False         False            False   True
# 461         False               False         False            False  False
# 462         False               False         False            False  False
#
#      Lantern Power Ring  Levitation  Light Control  Longevity  Magic  \
# 0                 False       False          False       True  False
# 1                 False       False          False       True  False
# 2                  True       False          False      False  False
# 3                 False       False          False      False  False
# 4                 False       False          False      False  False
# ..                  ...         ...            ...        ...    ...
# 458               False       False          False      False  False
# 459               False       False          False      False  False
# 460               False       False          False       True  False
# 461               False       False          False      False   True
# 462               False       False          False      False  False
#
#      Magic Resistance  Magnetism  Marksmanship  Matter Absorption  Melting  \
# 0               False      False         False              False    False
# 1               False      False          True              False    False
# 2               False      False         False              False    False
# 3               False      False         False              False    False
# 4               False      False         False               True    False
# ..                ...        ...           ...                ...      ...
# 458             False      False         False              False    False
# 459             False      False         False              False    False
# 460             False      False          True              False    False
# 461             False      False         False              False    False
# 462             False      False         False              False    False
#
#      Mind Blast  Mind Control  Mind Control Resistance  Molecular Combustion  \
# 0         False         False                    False                 False
# 1         False         False                    False                 False
# 2         False         False                    False                 False
# 3         False         False                    False                 False
# 4         False         False                    False                 False
# ..          ...           ...                      ...                   ...
# 458       False         False                    False                 False
# 459       False         False                    False                 False
# 460       False         False                    False                 False
# 461       False         False                    False                 False
# 462       False         False                    False                 False
#
#      Molecular Dissipation  Molecular Manipulation  Natural Armor  \
# 0                    False                   False          False
# 1                    False                   False          False
# 2                    False                   False          False
# 3                    False                   False          False
# 4                    False                    True           True
# ..                     ...                     ...            ...
# 458                  False                   False          False
# 459                  False                   False          False
# 460                  False                   False          False
# 461                  False                   False          False
# 462                  False                   False          False
#
#      Natural Weapons  Nova Force  Odin Force  Omnilingualism  Omnipotent  \
# 0              False       False       False           False       False
# 1              False       False       False           False       False
# 2              False       False       False           False       False
# 3              False       False       False           False       False
# 4              False       False       False           False       False
# ..               ...         ...         ...             ...         ...
# 458            False       False       False           False       False
# 459            False       False       False           False       False
# 460            False       False       False           False       False
# 461            False       False       False           False       False
# 462            False       False       False           False       False
#
#      Omnipresent  Omniscient  Omnitrix  Peak Human Condition  Phasing  \
# 0          False       False     False                 False    False
# 1          False       False     False                 False    False
# 2          False       False     False                 False    False
# 3          False       False     False                 False    False
# 4          False       False     False                 False    False
# ..           ...         ...       ...                   ...      ...
# 458        False       False     False                 False    False
# 459        False       False     False                 False    False
# 460        False       False     False                 False    False
# 461        False       False     False                 False    False
# 462        False       False     False                 False    False
#
#      Phoenix Force  Photographic Reflexes  Plant Control  Portal Creation  \
# 0            False                  False          False            False
# 1            False                  False          False            False
# 2            False                  False          False            False
# 3            False                  False          False            False
# 4            False                  False          False            False
# ..             ...                    ...            ...              ...
# 458          False                  False          False            False
# 459          False                  False          False            False
# 460          False                  False          False            False
# 461          False                  False          False            False
# 462          False                  False          False            False
#
#      Possession  Power Absorption  Power Augmentation  Power Cosmic  \
# 0         False             False               False         False
# 1         False             False               False         False
# 2         False             False               False         False
# 3         False             False               False         False
# 4         False             False               False         False
# ..          ...               ...                 ...           ...
# 458       False             False               False         False
# 459       False             False               False         False
# 460       False             False               False         False
# 461       False             False               False         False
# 462       False             False               False         False
#
#      Power Nullifier  Power Sense  Power Suit  Precognition  \
# 0              False        False       False         False
# 1              False        False       False         False
# 2              False        False       False         False
# 3              False        False       False         False
# 4              False        False       False         False
# ..               ...          ...         ...           ...
# 458            False        False       False         False
# 459            False        False       False         False
# 460            False        False       False          True
# 461            False        False       False         False
# 462            False        False       False         False
#
#      Probability Manipulation  Projection  Psionic Powers  \
# 0                       False       False           False
# 1                       False       False           False
# 2                       False       False           False
# 3                       False       False           False
# 4                       False       False           False
# ..                        ...         ...             ...
# 458                     False       False           False
# 459                     False       False           False
# 460                     False       False           False
# 461                      True       False           False
# 462                     False       False           False
#
#      Qwardian Power Ring  Radar Sense  Radiation Absorption  \
# 0                  False        False                 False
# 1                  False        False                 False
# 2                  False        False                 False
# 3                  False        False                 False
# 4                  False        False                 False
# ..                   ...          ...                   ...
# 458                False        False                 False
# 459                False        False                 False
# 460                False        False                 False
# 461                False        False                 False
# 462                False        False                 False
#
#      Radiation Control  Radiation Immunity  Reality Warping  Reflexes  \
# 0                False               False            False     False
# 1                False               False            False      True
# 2                False               False            False     False
# 3                False               False            False     False
# 4                False               False            False     False
# ..                 ...                 ...              ...       ...
# 458              False               False            False     False
# 459              False               False            False     False
# 460              False               False            False      True
# 461              False               False            False     False
# 462              False               False            False     False
#
#      Regeneration  Resurrection  Seismic Power  Self-Sustenance  \
# 0           False         False          False             True
# 1           False         False          False            False
# 2           False         False          False            False
# 3           False         False          False            False
# 4           False         False          False            False
# ..            ...           ...            ...              ...
# 458         False         False          False            False
# 459         False         False          False            False
# 460         False         False          False            False
# 461         False         False          False            False
# 462         False         False          False            False
#
#      Shapeshifting  Size Changing  Sonar  Sonic Scream  Spatial Awareness  \
# 0            False          False  False         False              False
# 1            False          False  False         False              False
# 2            False          False  False         False              False
# 3            False          False  False         False              False
# 4            False          False  False         False              False
# ..             ...            ...    ...           ...                ...
# 458          False           True  False         False              False
# 459          False           True  False         False              False
# 460          False          False  False         False              False
# 461          False          False  False         False              False
# 462          False          False  False         False              False
#
#      Speed Force  Stamina  Stealth  Sub-Mariner  Substance Secretion  \
# 0          False     True    False        False                False
# 1          False     True    False         True                False
# 2          False    False    False        False                False
# 3          False     True    False        False                False
# 4          False    False    False        False                False
# ..           ...      ...      ...          ...                  ...
# 458        False    False    False        False                False
# 459        False    False    False        False                False
# 460        False     True     True        False                False
# 461        False    False    False        False                False
# 462        False    False    False        False                False
#
#      Summoning  Super Breath  Super Speed  Super Strength  Symbiote Costume  \
# 0        False         False        False            True             False
# 1        False         False        False            True             False
# 2        False         False        False           False             False
# 3        False          True         True            True             False
# 4        False         False        False            True             False
# ..         ...           ...          ...             ...               ...
# 458      False         False        False           False             False
# 459      False         False        False           False             False
# 460      False         False         True           False             False
# 461      False         False        False           False             False
# 462      False         False         True           False             False
#
#      Technopath/Cyberpath  Telekinesis  Telepathy  Telepathy Resistance  \
# 0                   False        False      False                 False
# 1                   False        False       True                 False
# 2                   False        False      False                 False
# 3                   False        False      False                 False
# 4                   False        False      False                 False
# ..                    ...          ...        ...                   ...
# 458                 False        False      False                 False
# 459                 False        False      False                 False
# 460                 False         True       True                 False
# 461                 False        False       True                 False
# 462                 False        False      False                 False
#
#      Teleportation  Terrakinesis  The Force  Thirstokinesis  \
# 0            False         False      False           False
# 1            False         False      False           False
# 2            False         False      False           False
# 3            False         False      False           False
# 4            False         False      False           False
# ..             ...           ...        ...             ...
# 458          False         False      False           False
# 459          False         False      False           False
# 460          False         False       True           False
# 461          False          True      False           False
# 462          False         False      False           False
#
#      Time Manipulation  Time Travel  Toxin and Disease Control  \
# 0                False        False                      False
# 1                False        False                      False
# 2                False        False                      False
# 3                False        False                      False
# 4                False        False                      False
# ..                 ...          ...                        ...
# 458              False        False                      False
# 459              False        False                      False
# 460              False        False                      False
# 461              False        False                      False
# 462               True         True                      False
#
#      Toxin and Disease Resistance  Underwater breathing  Vision - Cryo  \
# 0                           False                 False          False
# 1                           False                  True          False
# 2                           False                 False          False
# 3                           False                 False          False
# 4                           False                 False          False
# ..                            ...                   ...            ...
# 458                         False                 False          False
# 459                         False                 False          False
# 460                         False                 False          False
# 461                         False                 False          False
# 462                         False                 False          False
#
#      Vision - Heat  Vision - Infrared  Vision - Microscopic  Vision - Night  \
# 0            False              False                 False           False
# 1            False              False                 False           False
# 2            False              False                 False           False
# 3            False              False                 False           False
# 4            False              False                 False           False
# ..             ...                ...                   ...             ...
# 458          False              False                 False           False
# 459          False              False                 False           False
# 460          False              False                 False           False
# 461          False              False                 False           False
# 462          False              False                 False           False
#
#      Vision - Telescopic  Vision - Thermal  Vision - X-Ray  Vitakinesis  \
# 0                  False             False           False        False
# 1                  False             False           False        False
# 2                  False             False           False        False
# 3                  False             False           False        False
# 4                  False             False           False        False
# ..                   ...               ...             ...          ...
# 458                False             False           False        False
# 459                False             False           False        False
# 460                False             False           False        False
# 461                False             False           False        False
# 462                False             False           False        False
#
#      Wallcrawling  Water Control  Weapon-based Powers  Weapons Master  \
# 0           False          False                False           False
# 1           False          False                False            True
# 2           False          False                False           False
# 3           False          False                False           False
# 4           False          False                False           False
# ..            ...            ...                  ...             ...
# 458         False          False                False           False
# 459         False          False                False           False
# 460         False          False                False            True
# 461         False           True                False           False
# 462         False          False                False           False
#
#      Weather Control  Web Creation  Wind Control
# 0              False         False         False
# 1              False         False         False
# 2              False         False         False
# 3              False         False         False
# 4              False         False         False
# ..               ...           ...           ...
# 458            False         False         False
# 459            False         False         False
# 460            False         False         False
# 461             True         False         False
# 462            False         False         False
#
# [463 rows x 177 columns]

# %% [markdown]
# ### Compare the average weight of super powers who have Super Speed to those who do not.

# %%
# Group the dataframe by super speed and find the mean of the weight
final_df.groupby('Super Speed')[['Weight (kg)']].mean()
# Out:
#              Weight (kg)
# Super Speed
# False         101.773585
# True          129.404040

# %% [markdown]
# Average weight for someone with super speed is 129.40 kg.

# %% [markdown]
# ### What is the average height of heroes for each publisher?

# %%
final_df.groupby("Publisher")[["Height (cm)"]].mean().sort_values(by="Height (cm)")
# Out:
#                    Height (cm)
# Publisher
# George Lucas        159.600000
# Shueisha            171.500000
# Dark Horse Comics   176.909091
# Unknown             178.000000
# Team Epic TV        180.750000
# Star Trek           181.500000
# DC Comics           181.923913
# Marvel Comics       191.546128
# Image Comics        211.000000

# %% [markdown]
# The average height for heroes in each publisher is between 160 kg to 211 k
